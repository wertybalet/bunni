# %% [markdown]
# <a href="https://colab.research.google.com/github/wertybalet/bunni/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python q.py Doght.txt
# Out:
# select your scanner:
# 1) ingram
# 2) asleep
# Choice [1/2]: 2
# [*] selected asleep
# [*] chunk 0 -> jade230_0.txt (Port: 37777,37778)
# [*] chunk 1 -> jade230_1.txt (Port: 37777,37778)
# [*] chunk 2 -> jade230_2.txt (Port: 37777,37778)
# [*] chunk 3 -> jade230_3.txt (Port: 37777,37778)
# [-] chunk_0.txt:1:1: invalid IP address on line #1
# [-] FAIL: error reading from include file
# Starting masscan 1.3.9-integration (http://bit.ly/14GZzcT) at 2026-03-08 01:28:09 GMT
# Initiating SYN Stealth Scan
# Scanning 16365780 hosts [2 ports/host]
# Starting masscan 1.3.9-integration (http://bit.ly/14GZzcT) at 2026-03-08 01:28:09 GMT
# Initiating SYN Stealth Scan
# Scanning 25757045 hosts [2 ports/host]
# Starting masscan 1.3.9-integration (http://bit.ly/14GZzcT) at 2026-03-08 01:28:09 GMT
# Initiating SYN Stealth Scan
# Scanning 51927504 hosts [2 ports/host]
# [+] 57728 ips gathered in jade230.txt
# [*] Launching Asleep on jade230.txt...
#               __
#   ____ ______/ /__  ___  ____
# ...
